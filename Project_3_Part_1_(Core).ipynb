# %% [markdown]
# Student: Satish Byrow

# %% [markdown]
# #**1. Goal**
# - For this project, you have been hired to produce a MySQL database on Movies from a subset of IMDB's publicly available dataset. Ultimately, you will use this database to analyze what makes a movie successful and will provide recommendations to the stakeholder on how to make a successful movie.

# %% [markdown]
# ##Dictionary
# TBC

# %% [markdown]
# #**2. Import and Loading**

# %% [markdown]
# ## Load Libraries

# %%
#Load Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Data

# %%
## Loading data from local repository
basics_url="Data/title.basics.tsv.gz"
rating_url="Data/title.ratings.tsv.gz"
akas_url="Data/title.akas.tsv.gz"

basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
ratings = pd.read_csv(rating_url, sep='\t', low_memory=False)
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
#Remove null values
basics.replace({'\\N':np.nan}, inplace=True)
ratings.replace({'\\N':np.nan}, inplace=True)
akas.replace({'\\N':np.nan}, inplace=True)

# %% [markdown]
# #**3. Explore Data Set**

# %%
#Check then data
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
#Check then data
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10243653 entries, 0 to 10243652
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 703.4+ MB

# %%
#Check then data
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2002
# 1  tt0000002            5.8       269
# 2  tt0000003            6.5      1892
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2678

# %%
#Check then data
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
#Check then data
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37510211 entries, 0 to 37510210
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.2+ GB

# %% [markdown]
# #**4. Clean Data Set**

# %%
#Check all records with runtime minutes null
basics['runtimeMinutes'].isnull().sum()
# Out:
# 7154281

# %%
#Check all records with runtime minutes null
indexNames = basics[(basics['runtimeMinutes'].isnull())].index 
# Delete these row indexes from dataFrame
basics.drop(indexNames , inplace=True)
basics['runtimeMinutes'].isnull().sum()
# Out:
# 0

# %%
#Check all records with genre minutes null
basics['genres'].isnull().sum()
# Out:
# 80733

# %%
#Check all records with genres null
indexNames = basics[(basics['genres'].isnull())].index 
# Delete these row indexes from dataFrame
basics.drop(indexNames , inplace=True)
basics['genres'].isnull().sum()
# Out:
# 0

# %%
#Count all records before
basics[~basics['titleType'].str.contains("Movie", case=False)].count()
# Out:
# tconst            2525073
# titleType         2525073
# primaryTitle      2525072
# originalTitle     2525072
# isAdult           2525073
# startYear         2341222
# endYear             52699
# runtimeMinutes    2525073
# genres            2525073
# dtype: int64

# %%
#Check all records with titletype that does not have movie
indexNames = basics[~(basics['titleType'].str.contains("Movie", case=False))].index 
# Delete these row indexes from dataFrame
basics.drop(indexNames , inplace=True)

# %%
#Check all records after
basics['titleType'].str.contains("Movie", case=False).count()
# Out:
# 483566

# %%
basics['startYear'].count()
# Out:
# 476578

# %%
#Check all records with year
basics = basics[basics['startYear'].str.contains('2000|2001|2002', regex=True, case=False)]
basics
# Out:
#              tconst  titleType                   primaryTitle  \
# 15176     tt0015414      movie         La tierra de los toros
# 33800     tt0034413      short             Youth Gets a Break
# 34800     tt0035423      movie                 Kate & Leopold
# 92617     tt0094718      short                        Beavers
# 93927     tt0096056      movie           Crime and Punishment
# ...             ...        ...                            ...
# 10242765  tt9914878  tvEpisode                 Episode #1.969
# 10242853  tt9915084  tvEpisode                      Making-of
# 10243215  tt9915932  videoGame                 Aero Dancing F
# 10243277  tt9916064  videoGame                      AeroWings
# 10243310  tt9916136  tvEpisode  Episode dated 7 February 2002
#
#                           originalTitle isAdult startYear endYear  \
# 15176            La tierra de los toros       0      2000      \N
# 33800                Youth Gets a Break       0      2001      \N
# 34800                    Kate & Leopold       0      2001      \N
# 92617                           Beavers       0      2002      \N
# 93927              Crime and Punishment       0      2002      \N
# ...                                 ...     ...       ...     ...
# 10242765                 Episode #1.969       0      2001      \N
# 10242853                      Making-of       0      2000      \N
# 10243215                 Aero Dancing F       0      2000      \N
# 10243277                 Aero Dancing i       0      2001      \N
# 10243310  Episode dated 7 February 2002       0      2002      \N
#
#          runtimeMinutes                  genres
# 15176                60                      \N
# 33800                20                   Short
# 34800               118  Comedy,Fantasy,Romance
# 92617                31       Documentary,Short
# 93927               126                   Drama
# ...                 ...                     ...
# 10242765             22   Drama,Fantasy,Romance
# 10242853             \N                  Comedy
# 10243215             \N                      \N
# 10243277             \N                      \N
# 10243310             \N          News,Talk-Show
#
# [319434 rows x 9 columns]

# %%
basics['startYear'].count()
# Out:
# 483566

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
is_us = (akas['region'] == 'US')
akas = akas[is_us]
keepers = (basics['tconst'].isin(akas['titleId']))
keepers
# Out:
# 15176       False
# 33800        True
# 34800        True
# 92617        True
# 93927        True
#             ...
# 10242765    False
# 10242853    False
# 10243215    False
# 10243277    False
# 10243310    False
# Name: tconst, Length: 319434, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#              tconst titleType  \
# 33800     tt0034413     short
# 34800     tt0035423     movie
# 92617     tt0094718     short
# 93927     tt0096056     movie
# 104782    tt0107194     short
# ...             ...       ...
# 10239444  tt9907718     short
# 10239773  tt9908414  tvSeries
# 10240402  tt9909874     video
# 10240422  tt9909916     video
# 10240434  tt9909954     video
#
#                                                primaryTitle  \
# 33800                                    Youth Gets a Break
# 34800                                        Kate & Leopold
# 92617                                               Beavers
# 93927                                  Crime and Punishment
# 104782                                              Imagine
# ...                                                     ...
# 10239444                                      Homeless Love
# 10239773                                           Block 13
# 10240402  Halloween: Resurrection - On the Set with Jami...
# 10240422  Halloween: Resurrection - Tour of Set with Pro...
# 10240434      Halloween: Resurrection - Head Cam Featurette
#
#                                               originalTitle isAdult startYear  \
# 33800                                    Youth Gets a Break       0      2001
# 34800                                        Kate & Leopold       0      2001
# 92617                                               Beavers       0      2002
# 93927                                  Crime and Punishment       0      2002
# 104782                                              Imagine       0      2002
# ...                                                     ...     ...       ...
# 10239444                                      Homeless Love       0      2002
# 10239773                                           Block 13       0      2000
# 10240402  Halloween: Resurrection - On the Set with Jami...       0      2002
# 10240422  Halloween: Resurrection - Tour of Set with Pro...       0      2002
# 10240434      Halloween: Resurrection - Head Cam Featurette       0      2002
#
#          endYear runtimeMinutes                    genres
# 33800         \N             20                     Short
# 34800         \N            118    Comedy,Fantasy,Romance
# 92617         \N             31         Documentary,Short
# 93927         \N            126                     Drama
# 104782        \N             22         Documentary,Short
# ...          ...            ...                       ...
# 10239444      \N             \N               Drama,Short
# 10239773    2003             10                 Animation
# 10240402      \N              4  Documentary,Horror,Short
# 10240422      \N              7  Documentary,Horror,Short
# 10240434      \N              4  Documentary,Horror,Short
#
# [41726 rows x 9 columns]

# %%
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 37509737  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 37509807  tt9916620         1                          The Copeland Case
# 37509896  tt9916702         1              Loving London: The Playground
# 37509939  tt9916756         1                   Pretty Pretty Black Girl
# 37509955  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US       \N  imdbDisplay                     \N               0
# 14           US       \N           \N  literal English title               0
# 33           US       \N  imdbDisplay                     \N               0
# 36           US       \N  alternative                     \N               0
# 41           US       \N  alternative                     \N               0
# ...         ...      ...          ...                    ...             ...
# 37509737     US       \N  imdbDisplay                     \N               0
# 37509807     US       \N  imdbDisplay                     \N               0
# 37509896     US       \N           \N                     \N               0
# 37509939     US       \N  imdbDisplay                     \N               0
# 37509955     US       \N  imdbDisplay                     \N               0
#
# [1471955 rows x 8 columns]

# %%
# Filter the basics table down to only include the US by using the filter ratings dataframe
#is_us = (akas['region'] == 'US')
#akas = akas[is_us]
keepers1 = (ratings['tconst'].isin(akas['titleId']))
keepers1
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1359499    False
# 1359500    False
# 1359501    False
# 1359502    False
# 1359503    False
# Name: tconst, Length: 1359504, dtype: bool

# %%
# Filter the basics table down to only include the US by using the filter ratings dataframe
ratings = ratings[keepers1]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2002
# 1        tt0000002            5.8       269
# 4        tt0000005            6.2      2678
# 5        tt0000006            5.0       182
# 6        tt0000007            5.4       838
# ...            ...            ...       ...
# 1359466  tt9916200            8.1       238
# 1359467  tt9916204            8.2       273
# 1359474  tt9916348            8.3        18
# 1359475  tt9916362            6.4      5570
# 1359480  tt9916428            3.5        17
#
# [511875 rows x 3 columns]

# %%
#remove orphaned records from akas
# Get indexes where name column doesn't have value tconst
#akas['titleId'].sum()
#indexNames = akas[~(akas['titleId'].isin(basics['tconst']))].index 
# Delete these row indexes from dataFrame
#akas.drop(indexNames , inplace=True)
#akas['titleId'].sum()

# %%
#remove orphaned records from ratings
# Get indexes where name column doesn't have value tconst
#ratings['tconst'].sum()
#indexNames = ratings[~(ratings['tconst'].isin(basics['tconst']))].index 
# Delete these row indexes from dataFrame
#ratings.drop(indexNames , inplace=True)
#ratings['tconst'].sum()

# %% [markdown]
# #**4. Write the data**

# %%
## Save current dataframe to file with underscore
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType          primaryTitle         originalTitle  isAdult  \
# 0  tt0034413     short    Youth Gets a Break    Youth Gets a Break        0
# 1  tt0035423     movie        Kate & Leopold        Kate & Leopold        0
# 2  tt0094718     short               Beavers               Beavers        0
# 3  tt0096056     movie  Crime and Punishment  Crime and Punishment        0
# 4  tt0107194     short               Imagine               Imagine        0
#
#    startYear endYear runtimeMinutes                  genres
# 0       2001      \N             20                   Short
# 1       2001      \N            118  Comedy,Fantasy,Romance
# 2       2002      \N             31       Documentary,Short
# 3       2002      \N            126                   Drama
# 4       2002      \N             22       Documentary,Short

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2002
# 1  tt0000002            5.8       269
# 2  tt0000005            6.2      2678
# 3  tt0000006            5.0       182
# 4  tt0000007            5.4       838

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0
