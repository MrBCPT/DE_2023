# %% [markdown]
# Student: Satish Byrow

# %% [markdown]
# #**1. Goal**
#  - Apply json.loads to convert strings back to dictionaries or lists.
#  -
# Handle dictionaries and lists stored within pandas DataFrames. -
# Leverage pandas string methods for filtering/separating data.er?

# %% [markdown]
# #**2. Import and Loading**

# %% [markdown]
# ## Load Libraries & Functions

# %%
#Load Libraries
import pandas as pd
import numpy as np
import os, json
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
# Open saved file and preview again
df = pd.read_csv("Data/final_results_crab_cakes.csv.gz", low_memory = False)
df.head()
# Out:
#                        id                                 alias  \
# 0  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 1  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
# 2  u65W69AhbjUlvJJBkEhGNQ        miss-shirleys-cafe-baltimore-9
# 3  6am8TZAFnvND52MOz-Yctg     mamas-on-the-half-shell-baltimore
# 4  p_XPpHiZbdOccx2jFUgZJA            the-local-oyster-baltimore
#
#                          name  \
# 0            Faidleys Seafood
# 1  Thames Street Oyster House
# 2         Miss Shirley's Cafe
# 3    Mama's On The Half Shell
# 4            The Local Oyster
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/OTjVDC...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/9FsOyV...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/HWY8OF...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/u_33ay...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/faidleys-seafood-balt...          1181
# 1  https://www.yelp.com/biz/thames-street-oyster-...          2726
# 2  https://www.yelp.com/biz/miss-shirleys-cafe-ba...          2918
# 3  https://www.yelp.com/biz/mamas-on-the-half-she...          1277
# 4  https://www.yelp.com/biz/the-local-oyster-balt...           217
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 2  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 3  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 4  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
#
#                                          coordinates            transactions  \
# 0    {'latitude': 39.291696, 'longitude': -76.62224}            ['delivery']
# 1     {'latitude': 39.28214, 'longitude': -76.59162}            ['delivery']
# 2  {'latitude': 39.2870995, 'longitude': -76.6053...  ['pickup', 'delivery']
# 3   {'latitude': 39.27986, 'longitude': -76.5752399}  ['pickup', 'delivery']
# 4  {'latitude': 39.2958288, 'longitude': -76.6188...            ['delivery']
#
#   price                                           location         phone  \
# 0    $$  {'address1': '203 N Paca St', 'address2': '', ...  1.410727e+10
# 1   $$$  {'address1': '1728 Thames St', 'address2': '',...  1.443450e+10
# 2    $$  {'address1': '750 E Pratt St', 'address2': '',...  1.410529e+10
# 3    $$  {'address1': '2901 Odonnell St', 'address2': '...  1.410276e+10
# 4    $$  {'address1': '520 Park Ave', 'address2': None,...  1.844748e+10
#
#     display_phone     distance
# 0  (410) 727-4898  1349.560720
# 1  (443) 449-7726  2090.712792
# 2  (410) 528-5373  1028.736468
# 3  (410) 276-3160  3328.825798
# 4  (844) 748-2537   966.729941

# %%
#check types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             429 non-null    object
#  1   alias          429 non-null    object
#  2   name           429 non-null    object
#  3   image_url      420 non-null    object
#  4   is_closed      429 non-null    bool
#  5   url            429 non-null    object
#  6   review_count   429 non-null    int64
#  7   categories     429 non-null    object
#  8   rating         429 non-null    float64
#  9   coordinates    429 non-null    object
#  10  transactions   429 non-null    object
#  11  price          339 non-null    object
#  12  location       429 non-null    object
#  13  phone          413 non-null    float64
#  14  display_phone  413 non-null    object
#  15  distance       429 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(11)
# memory usage: 50.8+ KB

# %%
# Exploring existing format with a few examples
df['display_phone'].head(2)
# Out:
# 0    (410) 727-4898
# 1    (443) 449-7726
# Name: display_phone, dtype: object

# %%
## adding expand=True
df['display_phone'].str.split(' ',expand=True)
# Out:
#          0         1
# 0    (410)  727-4898
# 1    (443)  449-7726
# 2    (410)  528-5373
# 3    (410)  276-3160
# 4    (844)  748-2537
# ..     ...       ...
# 424  (410)  889-8891
# 425  (410)  235-2300
# 426  (410)  522-7757
# 427  (410)  889-3663
# 428  (410)  243-1301
#
# [429 rows x 2 columns]

# %%
## save the 2 new columns into the dataframe
df[['area_code','phone_number']] = df['display_phone'].str.split(' ',expand=True)
df.head(2)
# Out:
#                        id                                 alias  \
# 0  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 1  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
#
#                          name  \
# 0            Faidleys Seafood
# 1  Thames Street Oyster House
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/OTjVDC...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/faidleys-seafood-balt...          1181
# 1  https://www.yelp.com/biz/thames-street-oyster-...          2726
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
#
#                                        coordinates  transactions price  \
# 0  {'latitude': 39.291696, 'longitude': -76.62224}  ['delivery']    $$
# 1   {'latitude': 39.28214, 'longitude': -76.59162}  ['delivery']   $$$
#
#                                             location         phone  \
# 0  {'address1': '203 N Paca St', 'address2': '', ...  1.410727e+10
# 1  {'address1': '1728 Thames St', 'address2': '',...  1.443450e+10
#
#     display_phone     distance area_code phone_number
# 0  (410) 727-4898  1349.560720     (410)     727-4898
# 1  (443) 449-7726  2090.712792     (443)     449-7726

# %%
## drop the original column 
df = df.drop(columns=['display_phone', 'phone'])
df.head(2)
# Out:
#                        id                                 alias  \
# 0  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 1  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
#
#                          name  \
# 0            Faidleys Seafood
# 1  Thames Street Oyster House
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/OTjVDC...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/faidleys-seafood-balt...          1181
# 1  https://www.yelp.com/biz/thames-street-oyster-...          2726
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
#
#                                        coordinates  transactions price  \
# 0  {'latitude': 39.291696, 'longitude': -76.62224}  ['delivery']    $$
# 1   {'latitude': 39.28214, 'longitude': -76.59162}  ['delivery']   $$$
#
#                                             location     distance area_code  \
# 0  {'address1': '203 N Paca St', 'address2': '', ...  1349.560720     (410)
# 1  {'address1': '1728 Thames St', 'address2': '',...  2090.712792     (443)
#
#   phone_number
# 0     727-4898
# 1     449-7726

# %%
# Make a list of all characters to replace
to_replace = ['(',')']
# run a loop to replace all of the characters in the list at once
for char in to_replace:
    df['area_code'] = df['area_code'].str.replace(char,'',regex=False)
    
df['area_code'].head()
# Out:
# 0    410
# 1    443
# 2    410
# 3    410
# 4    844
# Name: area_code, dtype: object

# %%
## examining a single value from the coordinates col
coord = df.loc[0,"coordinates"]
print(type(coord))
coord
# Out:
# <class 'str'>
# "{'latitude': 39.291696, 'longitude': -76.62224}"

# %%
coord = coord.replace("'",'"')
## now we can use json.loads
fixed_coord = json.loads(coord)
print(type(fixed_coord))
fixed_coord
# Out:
# <class 'dict'>
# {'latitude': 39.291696, 'longitude': -76.62224}

# %%
## use .str.replace to replace all single quotes
df['coordinates'] = df['coordinates'].str.replace("'",'"')
## Apply the json.loads to the full column
df['coordinates'] = df['coordinates'].apply(json.loads)
df['coordinates'].head()
# Out:
# 0      {'latitude': 39.291696, 'longitude': -76.62224}
# 1       {'latitude': 39.28214, 'longitude': -76.59162}
# 2    {'latitude': 39.2870995, 'longitude': -76.6053...
# 3     {'latitude': 39.27986, 'longitude': -76.5752399}
# 4    {'latitude': 39.2958288, 'longitude': -76.6188...
# Name: coordinates, dtype: object

# %%
## check a single value after transformation
test_coord = df.loc[0, 'coordinates']
print(type(test_coord))
test_coord
# Out:
# <class 'dict'>
# {'latitude': 39.291696, 'longitude': -76.62224}

# %%
lat_long = df['coordinates'].apply(pd.Series)
lat_long
# Out:
#       latitude  longitude
# 0    39.291696 -76.622240
# 1    39.282140 -76.591620
# 2    39.287099 -76.605366
# 3    39.279860 -76.575240
# 4    39.295829 -76.618891
# ..         ...        ...
# 424  39.330889 -76.634097
# 425  39.316500 -76.615560
# 426  39.281747 -76.581631
# 427  39.330860 -76.631610
# 428  39.330840 -76.633930
#
# [429 rows x 2 columns]

# %%
# concat long_lat with original dataframe
df = pd.concat((df, lat_long), axis = 1)
df.head(2)
# Out:
#                        id                                 alias  \
# 0  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 1  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
#
#                          name  \
# 0            Faidleys Seafood
# 1  Thames Street Oyster House
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/OTjVDC...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/faidleys-seafood-balt...          1181
# 1  https://www.yelp.com/biz/thames-street-oyster-...          2726
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
#
#                                        coordinates  transactions price  \
# 0  {'latitude': 39.291696, 'longitude': -76.62224}  ['delivery']    $$
# 1   {'latitude': 39.28214, 'longitude': -76.59162}  ['delivery']   $$$
#
#                                             location     distance area_code  \
# 0  {'address1': '203 N Paca St', 'address2': '', ...  1349.560720       410
# 1  {'address1': '1728 Thames St', 'address2': '',...  2090.712792       443
#
#   phone_number   latitude  longitude
# 0     727-4898  39.291696  -76.62224
# 1     449-7726  39.282140  -76.59162

# %%
df = df.drop(columns=['coordinates'])

# %%
## showing the lists are really strings
df.loc[2,'transactions']
# Out:
# "['pickup', 'delivery']"

# %%
# Create a new column where the single quotes are replaced by double quotes
df['transactions_split'] = df['transactions'].str.replace("'",'"')
# Apply json.loads to entire column
df['transactions_split'] = df['transactions_split'].apply(json.loads)
# check results
df['transactions_split'].head()
# Out:
# 0            [delivery]
# 1            [delivery]
# 2    [pickup, delivery]
# 3    [pickup, delivery]
# 4            [delivery]
# Name: transactions_split, dtype: object

# %%
df['transactions_split'].value_counts()
# Out:
# [delivery, pickup]                            119
# [pickup, delivery]                            107
# [delivery]                                    105
# []                                             86
# [pickup]                                        6
# [pickup, delivery, restaurant_reservation]      2
# [delivery, pickup, restaurant_reservation]      2
# [restaurant_reservation]                        2
# Name: transactions_split, dtype: int64

# %%
## exploding the column of lists
exploded = df.explode('transactions_split')
exploded[['name','transactions','transactions_split']].head(5)
# Out:
#                          name            transactions transactions_split
# 0            Faidleys Seafood            ['delivery']           delivery
# 1  Thames Street Oyster House            ['delivery']           delivery
# 2         Miss Shirley's Cafe  ['pickup', 'delivery']             pickup
# 2         Miss Shirley's Cafe  ['pickup', 'delivery']           delivery
# 3    Mama's On The Half Shell  ['pickup', 'delivery']             pickup

# %%
## saving the unique values from the exploded column
cols_to_make = exploded['transactions_split'].dropna().unique()
cols_to_make
# Out:
# array(['delivery', 'pickup', 'restaurant_reservation'], dtype=object)

# %%
for col in cols_to_make:
    df[col] = df['transactions'].str.contains(col)
df.head()
# Out:
#                        id                                 alias  \
# 0  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 1  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
# 2  u65W69AhbjUlvJJBkEhGNQ        miss-shirleys-cafe-baltimore-9
# 3  6am8TZAFnvND52MOz-Yctg     mamas-on-the-half-shell-baltimore
# 4  p_XPpHiZbdOccx2jFUgZJA            the-local-oyster-baltimore
#
#                          name  \
# 0            Faidleys Seafood
# 1  Thames Street Oyster House
# 2         Miss Shirley's Cafe
# 3    Mama's On The Half Shell
# 4            The Local Oyster
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/OTjVDC...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/9FsOyV...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/HWY8OF...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/u_33ay...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/faidleys-seafood-balt...          1181
# 1  https://www.yelp.com/biz/thames-street-oyster-...          2726
# 2  https://www.yelp.com/biz/miss-shirleys-cafe-ba...          2918
# 3  https://www.yelp.com/biz/mamas-on-the-half-she...          1277
# 4  https://www.yelp.com/biz/the-local-oyster-balt...           217
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 2  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 3  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 4  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
#
#              transactions  ...  \
# 0            ['delivery']  ...
# 1            ['delivery']  ...
# 2  ['pickup', 'delivery']  ...
# 3  ['pickup', 'delivery']  ...
# 4            ['delivery']  ...
#
#                                             location     distance  area_code  \
# 0  {'address1': '203 N Paca St', 'address2': '', ...  1349.560720        410
# 1  {'address1': '1728 Thames St', 'address2': '',...  2090.712792        443
# 2  {'address1': '750 E Pratt St', 'address2': '',...  1028.736468        410
# 3  {'address1': '2901 Odonnell St', 'address2': '...  3328.825798        410
# 4  {'address1': '520 Park Ave', 'address2': None,...   966.729941        844
#
#   phone_number   latitude  longitude  transactions_split delivery  pickup  \
# 0     727-4898  39.291696 -76.622240          [delivery]     True   False
# 1     449-7726  39.282140 -76.591620          [delivery]     True   False
# 2     528-5373  39.287099 -76.605366  [pickup, delivery]     True    True
# 3     276-3160  39.279860 -76.575240  [pickup, delivery]     True    True
# 4     748-2537  39.295829 -76.618891          [delivery]     True   False
#
#    restaurant_reservation
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Clean the Data

# %%
#Duplicate count
## Display the number of duplicate rows in the dataset
print(f'There are {df.duplicated().sum()} duplicate rows.')
# Out:
# There are 0 duplicate rows.

# %%
#Duplicate count
## Display the number of duplicate rows in the dataset
print(f'There are {df1.duplicated().sum()} duplicate rows.')
# Out:
# There are 0 duplicate rows.

# %%
# Display the total number of missing values
print(f'There are {df.isna().sum().sum()} missing values.')
# Out:
# There are 0 missing values.

# %%
# Display the total number of missing values
print(f'There are {df1.isna().sum().sum()} missing values.')
# Out:
# There are 0 missing values.

# %%
#Check for categorical descrepencies
for col in df.select_dtypes(include='object').columns:
  print(df[col].value_counts())
# Out:
# Spider-Man|Marvel Comics       3
# Black Canary|DC Comics         2
# Nova|Marvel Comics             2
# Toxin|Marvel Comics            2
# Batman|DC Comics               2
#                               ..
# Fabian Cortez|Marvel Comics    1
# Exodus|Marvel Comics           1
# Evilhawk|Marvel Comics         1
# Evil Deadpool|Marvel Comics    1
# Zoom|DC Comics                 1
# Name: Hero|Publisher, Length: 457, dtype: int64
# Male       321
# Female     134
# Unknown      8
# Name: Gender, dtype: int64
# Human                156
# Unknown              145
# Mutant                51
# Human / Radiation     11
# Android                7
# Symbiote               7
# Alien                  6
# Demon                  6
# Cyborg                 6
# Kryptonian             5
# Atlantean              5
# Asgardian              5
# Inhuman                4
# New God                3
# Human-Kree             2
# Eternal                2
# Demi-God               2
# Saiyan                 2
# Amazon                 2
# Human / Altered        2
# Metahuman              2
# God / Eternal          2
# Human-Vulcan           1
# Martian                1
# Zombie                 1
# Korugaran              1
# Talokite               1
# Clone                  1
# Human-Spartoi          1
# Animal                 1
# Yautja                 1
# Human / Cosmic         1
# Tamaranean             1
# Mutant / Clone         1
# Luphomoid              1
# Frost Giant            1
# Strontian              1
# Czarnian               1
# Bolovaxian             1
# Human-Vuldarian        1
# Flora Colossus         1
# Gorilla                1
# Icthyo Sapien          1
# Zen-Whoberian          1
# Cosmic Entity          1
# Kakarantharaian        1
# Vampire                1
# Bizarro                1
# Neyaphem               1
# Xenomorph XX121        1
# Ungaran                1
# Yoda's species         1
# Name: Race, dtype: int64
# good       311
# bad        132
# neutral     17
# Unknown      3
# Name: Alignment, dtype: int64
# Black               127
# Blond                74
# Brown                69
# No Hair              52
# Red                  41
# White                22
# Unknown              18
# Auburn               13
# Green                 6
# Strawberry Blond      5
# Purple                4
# Brown / White         4
# Grey                  4
# black                 3
# blond                 3
# Silver                3
# Blue                  2
# Orange                2
# Pink                  1
# Gold                  1
# Red / White           1
# Indigo                1
# Red / Orange          1
# Red / Grey            1
# Brownn                1
# Yellow                1
# Orange / White        1
# Magenta               1
# Black / Blue          1
# Name: Hair color, dtype: int64
# blue                       182
# brown                      102
# green                       61
# red                         38
# Unknown                     17
# yellow                      13
# black                       12
# white                       10
# grey                         5
# hazel                        5
# gold                         3
# purple                       3
# yellow (without irises)      2
# amber                        2
# violet                       2
# white / red                  1
# indigo                       1
# silver                       1
# green / blue                 1
# blue / white                 1
# yellow / blue                1
# Name: Eye color, dtype: int64
# Unknown       409
# green          15
# blue            7
# red             7
# white           5
# grey            4
# silver          4
# purple          3
# gold            2
# pink            2
# yellow          2
# black           1
# blue-white      1
# orange          1
# Name: Skin color, dtype: int64
# {'Height': '183.0 cm', 'Weight': '90.0 kg'}     6
# {'Height': '183.0 cm', 'Weight': '86.0 kg'}     6
# {'Height': '178.0 cm', 'Weight': '79.0 kg'}     6
# {'Height': '188.0 cm', 'Weight': '95.0 kg'}     6
# {'Height': '180.0 cm', 'Weight': '81.0 kg'}     6
#                                                ..
# {'Height': '701.0 cm', 'Weight': '4.0 kg'}      1
# {'Height': '185.0 cm', 'Weight': '89.0 kg'}     1
# {'Height': '259.0 cm', 'Weight': '158.0 kg'}    1
# {'Height': '191.0 cm', 'Weight': '65.0 kg'}     1
# {'Height': '66.0 cm', 'Weight': '17.0 kg'}      1
# Name: Measurements, Length: 287, dtype: int64

# %%
#Replace values
df["Hair color"].replace("black","Black", inplace=True)
df["Hair color"].replace("blond","Blond", inplace=True)
df["Hair color"].replace("Brownn","Brown", inplace=True)

# %%
#REplace values on measurements
df['Measurements'] = df['Measurements'].str.replace("'",'"')
df['Measurements'] = df['Measurements'].str.replace(" cm","")
df['Measurements'] = df['Measurements'].str.replace(" kg","")
df['Measurements'] = df['Measurements'].apply(json.loads)
df['Measurements']
# Out:
# 0      {'Height': '203.0', 'Weight': '441.0'}
# 1       {'Height': '191.0', 'Weight': '65.0'}
# 2       {'Height': '185.0', 'Weight': '90.0'}
# 3      {'Height': '203.0', 'Weight': '441.0'}
# 4      {'Height': '193.0', 'Weight': '122.0'}
#                         ...
# 458     {'Height': '183.0', 'Weight': '83.0'}
# 459     {'Height': '165.0', 'Weight': '52.0'}
# 460      {'Height': '66.0', 'Weight': '17.0'}
# 461     {'Height': '170.0', 'Weight': '57.0'}
# 462     {'Height': '185.0', 'Weight': '81.0'}
# Name: Measurements, Length: 463, dtype: object

# %%
#Split measurements
height_weight= df['Measurements'].apply(pd.Series)
height_weight
# Out:
#     Height Weight
# 0    203.0  441.0
# 1    191.0   65.0
# 2    185.0   90.0
# 3    203.0  441.0
# 4    193.0  122.0
# ..     ...    ...
# 458  183.0   83.0
# 459  165.0   52.0
# 460   66.0   17.0
# 461  170.0   57.0
# 462  185.0   81.0
#
# [463 rows x 2 columns]

# %%
# concat height_weight with original dataframe
df = pd.concat((df, height_weight), axis = 1)
df.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                            Measurements Height Weight
# 0    yellow    Unknown  {'Height': '203.0', 'Weight': '441.0'}  203.0  441.0
# 1      blue       blue   {'Height': '191.0', 'Weight': '65.0'}  191.0   65.0

# %%
#Convert to Numeric
df["Height"] = df["Height"].astype(float)
df["Weight"] = df["Weight"].astype(float)

# %%
#drop measurements
df = df.drop(columns=['Measurements'])
df.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color  Height  Weight
# 0    yellow    Unknown   203.0   441.0
# 1      blue       blue   191.0    65.0

# %%
#Split Hero|Plublisher
df[['Hero','Publisher']] = df['Hero|Publisher'].str.split('|',expand=True)
df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  Height  Weight           Hero  \
# 0    No Hair    yellow    Unknown   203.0   441.0         A-Bomb
# 1    No Hair      blue       blue   191.0    65.0     Abe Sapien
# 2    No Hair      blue        red   185.0    90.0       Abin Sur
# 3    No Hair     green    Unknown   203.0   441.0    Abomination
# 4    No Hair      blue    Unknown   193.0   122.0  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
#Set column order
df = df.drop(columns=['Hero|Publisher'])
df = df[['Hero', 'Publisher', 'Gender', 'Eye color','Race','Hair color','Height', 'Skin color','Alignment','Weight']]
df.head()
# Out:
#             Hero          Publisher Gender Eye color               Race  \
# 0         A-Bomb      Marvel Comics   Male    yellow              Human
# 1     Abe Sapien  Dark Horse Comics   Male      blue      Icthyo Sapien
# 2       Abin Sur          DC Comics   Male      blue            Ungaran
# 3    Abomination      Marvel Comics   Male     green  Human / Radiation
# 4  Absorbing Man      Marvel Comics   Male      blue              Human
#
#   Hair color  Height Skin color Alignment  Weight
# 0    No Hair   203.0    Unknown      good   441.0
# 1    No Hair   191.0       blue      good    65.0
# 2    No Hair   185.0        red      good    90.0
# 3    No Hair   203.0    Unknown       bad   441.0
# 4    No Hair   193.0    Unknown       bad   122.0

# %%
#Check for categorical descrepencies
for col in df1.select_dtypes(include='object').columns:
  print(df1[col].value_counts())
# Out:
# 3-D Man            1
# Namora             1
# Naruto Uzumaki     1
# Nathan Petrelli    1
# Nebula             1
#                   ..
# Evilhawk           1
# Exodus             1
# Fabian Cortez      1
# Falcon             1
# Zoom               1
# Name: hero_names, Length: 667, dtype: int64
# Intelligence                                                                                                                                                                                                                                                         8
# Durability,Super Strength                                                                                                                                                                                                                                            5
# Agility,Stealth,Marksmanship,Weapons Master,Stamina                                                                                                                                                                                                                  4
# Marksmanship                                                                                                                                                                                                                                                         4
# Teleportation                                                                                                                                                                                                                                                        4
#                                                                                                                                                                                                                                                                     ..
# Accelerated Healing,Flight,Telepathy,Energy Blasts,Teleportation,Telekinesis,Astral Projection,Psionic Powers,Mind Blast,Regeneration,Illusions,Resurrection                                                                                                         1
# Flight,Telepathy,Animal Oriented Powers,Gliding                                                                                                                                                                                                                      1
# Accelerated Healing,Durability,Energy Absorption,Flight,Super Strength,Telepathy,Energy Blasts,Size Changing,Super Speed,Darkforce Manipulation,Enhanced Senses,Phasing,Invulnerability,Self-Sustenance,Gravity Control,Energy Manipulation,Time Travel,Illusions    1
# Agility,Accelerated Healing,Super Strength,Super Speed,Animal Oriented Powers,Enhanced Senses,Jump,Reflexes,Natural Weapons                                                                                                                                          1
# Super Speed,Intangibility,Time Travel,Time Manipulation                                                                                                                                                                                                              1
# Name: Powers, Length: 608, dtype: int64

# %%
#Split the values to only return unique
powers_split = df1['Powers'].str.split(",")
unique_powers = powers_split.explode().unique()
unique_powers
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
#        'Enhanced Senses', 'Jump', 'Shapeshifting', 'Elasticity',
#        'Substance Secretion', 'Enhanced Hearing', 'Adaptation', 'Gliding',
#        'Natural Weapons', 'Wallcrawling', 'Vision - Thermal',
#        'Power Augmentation', 'Cryokinesis', 'Duplication',
#        'Weapon-based Powers', 'Fire Control', 'Enhanced Memory',
#        'Energy Constructs', 'Power Absorption', 'Time Travel',
#        'Enhanced Smell', 'Water Control', 'Vision - Telescopic',
#        'Magnetism', 'Vision - Microscopic', 'Vision - Night',
#        'Vision - Heat', 'Vision - X-Ray', 'Psionic Powers',
#        'Toxin and Disease Resistance', 'Animal Attributes',
#        'Animal Oriented Powers', 'Toxin and Disease Control', 'Empathy',
#        'Animal Control', 'Darkforce Manipulation', 'Time Manipulation',
#        'Reality Warping', 'Web Creation', 'Symbiote Costume',
#        'Telekinesis', 'Levitation', 'Biokinesis', 'Sonar',
#        'Enhanced Touch', 'Seismic Power', 'Energy Armor',
#        'Omnilingualism', 'Radiation Immunity', 'Density Control',
#        'Light Control', 'Illumination', 'Molecular Combustion',
#        'Astral Travel', 'Precognition', 'Intangibility', 'Illusions',
#        'Audio Control', 'Sonic Scream', 'Peak Human Condition',
#        'Vision - Infrared', 'Dexterity', 'Omnitrix', 'Omnipotent',
#        'Possession', 'Energy Resistance', 'Vision - Cryo', 'Mind Control',
#        'Mind Blast', 'Clairvoyance', 'Probability Manipulation',
#        'Death Touch', 'Electrokinesis', 'Gravity Control',
#        'Technopath/Cyberpath', 'Radar Sense', 'Astral Projection',
#        'Cloaking', 'Telepathy Resistance', 'Mind Control Resistance',
#        'Hyperkinesis', 'Spatial Awareness', 'Radiation Control',
#        'Radiation Absorption', 'Magic Resistance', 'Element Control',
#        'Plant Control', 'Terrakinesis', 'Power Sense', 'Wind Control',
#        'Qwardian Power Ring', 'Echolocation', 'Resurrection', 'The Force',
#        'Summoning', 'Banish', 'Molecular Dissipation',
#        'Electrical Transport', 'Speed Force', 'Grim Reaping',
#        'Portal Creation', 'Vitakinesis', 'Projection', 'Insanity',
#        'Photographic Reflexes', 'Anti-Gravity', 'Thirstokinesis',
#        'Power Nullifier', 'Weather Control', 'Omnipresent', 'Omniscient',
#        'Hair Manipulation', 'Nova Force', 'Odin Force', 'Phoenix Force',
#        'Intuitive aptitude', 'Melting', 'Changing Armor'], dtype=object)

# %%
#Convert array to dataframe and then explode
df1['Powers'] = pd.DataFrame(unique_powers)
exploded = df1.explode('Powers')
exploded[['hero_names','Powers']].head(5)
# Out:
#     hero_names               Powers
# 0      3-D Man              Agility
# 1       A-Bomb       Super Strength
# 2   Abe Sapien              Stamina
# 3     Abin Sur          Super Speed
# 4  Abomination  Accelerated Healing

# %%
## exploding the column of lists
## saving the unique values from the exploded column
cols_to_make = exploded['Powers'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
#        'Enhanced Senses', 'Jump', 'Shapeshifting', 'Elasticity',
#        'Substance Secretion', 'Enhanced Hearing', 'Adaptation', 'Gliding',
#        'Natural Weapons', 'Wallcrawling', 'Vision - Thermal',
#        'Power Augmentation', 'Cryokinesis', 'Duplication',
#        'Weapon-based Powers', 'Fire Control', 'Enhanced Memory',
#        'Energy Constructs', 'Power Absorption', 'Time Travel',
#        'Enhanced Smell', 'Water Control', 'Vision - Telescopic',
#        'Magnetism', 'Vision - Microscopic', 'Vision - Night',
#        'Vision - Heat', 'Vision - X-Ray', 'Psionic Powers',
#        'Toxin and Disease Resistance', 'Animal Attributes',
#        'Animal Oriented Powers', 'Toxin and Disease Control', 'Empathy',
#        'Animal Control', 'Darkforce Manipulation', 'Time Manipulation',
#        'Reality Warping', 'Web Creation', 'Symbiote Costume',
#        'Telekinesis', 'Levitation', 'Biokinesis', 'Sonar',
#        'Enhanced Touch', 'Seismic Power', 'Energy Armor',
#        'Omnilingualism', 'Radiation Immunity', 'Density Control',
#        'Light Control', 'Illumination', 'Molecular Combustion',
#        'Astral Travel', 'Precognition', 'Intangibility', 'Illusions',
#        'Audio Control', 'Sonic Scream', 'Peak Human Condition',
#        'Vision - Infrared', 'Dexterity', 'Omnitrix', 'Omnipotent',
#        'Possession', 'Energy Resistance', 'Vision - Cryo', 'Mind Control',
#        'Mind Blast', 'Clairvoyance', 'Probability Manipulation',
#        'Death Touch', 'Electrokinesis', 'Gravity Control',
#        'Technopath/Cyberpath', 'Radar Sense', 'Astral Projection',
#        'Cloaking', 'Telepathy Resistance', 'Mind Control Resistance',
#        'Hyperkinesis', 'Spatial Awareness', 'Radiation Control',
#        'Radiation Absorption', 'Magic Resistance', 'Element Control',
#        'Plant Control', 'Terrakinesis', 'Power Sense', 'Wind Control',
#        'Qwardian Power Ring', 'Echolocation', 'Resurrection', 'The Force',
#        'Summoning', 'Banish', 'Molecular Dissipation',
#        'Electrical Transport', 'Speed Force', 'Grim Reaping',
#        'Portal Creation', 'Vitakinesis', 'Projection', 'Insanity',
#        'Photographic Reflexes', 'Anti-Gravity', 'Thirstokinesis',
#        'Power Nullifier', 'Weather Control', 'Omnipresent', 'Omniscient',
#        'Hair Manipulation', 'Nova Force', 'Odin Force', 'Phoenix Force',
#        'Intuitive aptitude', 'Melting', 'Changing Armor'], dtype=object)

# %%
for col in cols_to_make:
    df1[col] = df1['Powers'].str.contains(col)
df1.head()
# Out:
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
# C:\Users\sbyrow\AppData\Local\Temp\ipykernel_20436\779434845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1[col] = df1['Powers'].str.contains(col)
#     hero_names               Powers Agility Super Strength Stamina  \
# 0      3-D Man              Agility    True          False   False
# 1       A-Bomb       Super Strength   False           True   False
# 2   Abe Sapien              Stamina   False          False    True
# 3     Abin Sur          Super Speed   False          False   False
# 4  Abomination  Accelerated Healing   False          False   False
#
#   Super Speed Accelerated Healing Durability Longevity Camouflage  ...  \
# 0       False               False      False     False      False  ...
# 1       False               False      False     False      False  ...
# 2       False               False      False     False      False  ...
# 3        True               False      False     False      False  ...
# 4       False                True      False     False      False  ...
#
#   Weather Control Omnipresent Omniscient Hair Manipulation Nova Force  \
# 0           False       False      False             False      False
# 1           False       False      False             False      False
# 2           False       False      False             False      False
# 3           False       False      False             False      False
# 4           False       False      False             False      False
#
#   Odin Force Phoenix Force Intuitive aptitude Melting Changing Armor
# 0      False         False              False   False          False
# 1      False         False              False   False          False
# 2      False         False              False   False          False
# 3      False         False              False   False          False
# 4      False         False              False   False          False
#
# [5 rows x 169 columns]

# %%
#Drop Powers
df1 = df1.drop(columns=['Powers'])
df1.head(2)
# Out:
#   hero_names Agility Super Strength Stamina Super Speed Accelerated Healing  \
# 0    3-D Man    True          False   False       False               False
# 1     A-Bomb   False           True   False       False               False
#
#   Durability Longevity Camouflage Self-Sustenance  ... Weather Control  \
# 0      False     False      False           False  ...           False
# 1      False     False      False           False  ...           False
#
#   Omnipresent Omniscient Hair Manipulation Nova Force Odin Force  \
# 0       False      False             False      False      False
# 1       False      False             False      False      False
#
#   Phoenix Force Intuitive aptitude Melting Changing Armor
# 0         False              False   False          False
# 1         False              False   False          False
#
# [2 rows x 168 columns]

# %%
#Rename column
df1.rename(columns={'hero_names': 'Hero'}, inplace=True)

# %% [markdown]
# ## Combine Data

# %%
#Combine the data sets
df_main = pd.concat([df, df1], axis = 1)
df_main.head(30)
# Out:
#                Hero          Publisher  Gender Eye color               Race  \
# 0            A-Bomb      Marvel Comics    Male    yellow              Human
# 1        Abe Sapien  Dark Horse Comics    Male      blue      Icthyo Sapien
# 2          Abin Sur          DC Comics    Male      blue            Ungaran
# 3       Abomination      Marvel Comics    Male     green  Human / Radiation
# 4     Absorbing Man      Marvel Comics    Male      blue              Human
# 5      Adam Strange          DC Comics    Male      blue              Human
# 6         Agent Bob      Marvel Comics    Male     brown              Human
# 7        Agent Zero      Marvel Comics    Male   Unknown            Unknown
# 8        Air-Walker      Marvel Comics    Male      blue            Unknown
# 9              Ajax      Marvel Comics    Male     brown             Cyborg
# 10       Alan Scott          DC Comics    Male      blue            Unknown
# 11            Alien  Dark Horse Comics    Male   Unknown    Xenomorph XX121
# 12            Amazo          DC Comics    Male       red            Android
# 13             Ammo      Marvel Comics    Male     brown              Human
# 14            Angel      Marvel Comics    Male      blue            Unknown
# 15       Angel Dust      Marvel Comics  Female    yellow             Mutant
# 16  Angel Salvadore      Marvel Comics  Female     brown            Unknown
# 17       Animal Man          DC Comics    Male      blue              Human
# 18        Annihilus      Marvel Comics    Male     green            Unknown
# 19          Ant-Man      Marvel Comics    Male      blue              Human
# 20       Ant-Man II      Marvel Comics    Male      blue              Human
# 21       Anti-Venom      Marvel Comics    Male      blue           Symbiote
# 22       Apocalypse      Marvel Comics    Male       red             Mutant
# 23          Aqualad          DC Comics    Male      blue          Atlantean
# 24          Aquaman          DC Comics    Male      blue          Atlantean
# 25          Arachne      Marvel Comics  Female      blue              Human
# 26        Archangel      Marvel Comics    Male      blue             Mutant
# 27         Arclight      Marvel Comics  Female    violet            Unknown
# 28           Ardina      Marvel Comics  Female     white              Alien
# 29             Ares      Marvel Comics    Male     brown            Unknown
#
#    Hair color  Height Skin color Alignment  Weight  ... Weather Control  \
# 0     No Hair   203.0    Unknown      good   441.0  ...           False
# 1     No Hair   191.0       blue      good    65.0  ...           False
# 2     No Hair   185.0        red      good    90.0  ...           False
# 3     No Hair   203.0    Unknown       bad   441.0  ...           False
# 4     No Hair   193.0    Unknown       bad   122.0  ...           False
# 5       Blond   185.0    Unknown      good    88.0  ...           False
# 6       Brown   178.0    Unknown      good    81.0  ...           False
# 7     Unknown   191.0    Unknown      good   104.0  ...           False
# 8       White   188.0    Unknown       bad   108.0  ...           False
# 9       Black   193.0    Unknown       bad    90.0  ...           False
# 10      Blond   180.0    Unknown      good    90.0  ...           False
# 11    No Hair   244.0      black       bad   169.0  ...           False
# 12    Unknown   257.0    Unknown       bad   173.0  ...           False
# 13      Black   188.0    Unknown       bad   101.0  ...           False
# 14      Blond   183.0    Unknown      good    68.0  ...           False
# 15      Black   165.0    Unknown      good    57.0  ...           False
# 16      Black   163.0    Unknown      good    54.0  ...           False
# 17      Blond   183.0    Unknown      good    83.0  ...           False
# 18    No Hair   180.0    Unknown       bad    90.0  ...           False
# 19      Blond   211.0    Unknown      good   122.0  ...           False
# 20      Blond   183.0    Unknown      good    86.0  ...           False
# 21      Blond   229.0    Unknown   Unknown   358.0  ...           False
# 22      Black   213.0       grey       bad   135.0  ...           False
# 23      Black   178.0    Unknown      good   106.0  ...           False
# 24      Blond   185.0    Unknown      good   146.0  ...           False
# 25      Blond   175.0    Unknown      good    63.0  ...           False
# 26      Blond   183.0       blue      good    68.0  ...           False
# 27     Purple   173.0    Unknown       bad    57.0  ...           False
# 28     Orange   193.0       gold      good    98.0  ...           False
# 29      Brown   185.0    Unknown      good   270.0  ...           False
#
#    Omnipresent Omniscient Hair Manipulation Nova Force Odin Force  \
# 0        False      False             False      False      False
# 1        False      False             False      False      False
# 2        False      False             False      False      False
# 3        False      False             False      False      False
# 4        False      False             False      False      False
# 5        False      False             False      False      False
# 6        False      False             False      False      False
# 7        False      False             False      False      False
# 8        False      False             False      False      False
# 9        False      False             False      False      False
# 10       False      False             False      False      False
# 11       False      False             False      False      False
# 12       False      False             False      False      False
# 13       False      False             False      False      False
# 14       False      False             False      False      False
# 15       False      False             False      False      False
# 16       False      False             False      False      False
# 17       False      False             False      False      False
# 18       False      False             False      False      False
# 19       False      False             False      False      False
# 20       False      False             False      False      False
# 21       False      False             False      False      False
# 22       False      False             False      False      False
# 23       False      False             False      False      False
# 24       False      False             False      False      False
# 25       False      False             False      False      False
# 26       False      False             False      False      False
# 27       False      False             False      False      False
# 28       False      False             False      False      False
# 29       False      False             False      False      False
#
#    Phoenix Force Intuitive aptitude Melting Changing Armor
# 0          False              False   False          False
# 1          False              False   False          False
# 2          False              False   False          False
# 3          False              False   False          False
# 4          False              False   False          False
# 5          False              False   False          False
# 6          False              False   False          False
# 7          False              False   False          False
# 8          False              False   False          False
# 9          False              False   False          False
# 10         False              False   False          False
# 11         False              False   False          False
# 12         False              False   False          False
# 13         False              False   False          False
# 14         False              False   False          False
# 15         False              False   False          False
# 16         False              False   False          False
# 17         False              False   False          False
# 18         False              False   False          False
# 19         False              False   False          False
# 20         False              False   False          False
# 21         False              False   False          False
# 22         False              False   False          False
# 23         False              False   False          False
# 24         False              False   False          False
# 25         False              False   False          False
# 26         False              False   False          False
# 27         False              False   False          False
# 28         False              False   False          False
# 29         False              False   False          False
#
# [30 rows x 178 columns]

# %% [markdown]
# ## Explore the Data

# %%
#Compare the average weight of super powers who have Super Speed to those who do not.
#df_main.groupby('Hero').contains('Super Speed')['Weight'].mean()
df_main.groupby('Super Speed')['Weight'].mean()
# Out:
# Super Speed
# False    107.343373
# True     441.000000
# Name: Weight, dtype: float64

# %%
#What is the average height of heroes for each publisher?
df_main.groupby('Publisher')['Height'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height, dtype: float64
