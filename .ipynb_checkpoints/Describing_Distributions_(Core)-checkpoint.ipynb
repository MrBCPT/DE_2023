# %% [markdown]
# Student: Satish Byrow

# %% [markdown]
# #**1. Goal**
# - Analyzing & visualizing several feature
# - The features to analyze: VitD_level,
# Doc_vist ,
# TotalCharr?

# %% [markdown]
# #**2. Import and Loading**

# %% [markdown]
# ## Load Libraries & Functions

# %%
#Load Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
# Open saved file and preview again
df_main = pd.read_csv("Data/medData.csv", low_memory = False)
df_main.info()
#Make a copy
df = df_main
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               995 non-null    object
#  1   Lat                 1000 non-null   float64
#  2   Lng                 1000 non-null   float64
#  3   Area                995 non-null    object
#  4   Children            993 non-null    float64
#  5   Age                 1000 non-null   int64
#  6   Income              1000 non-null   float64
#  7   Marital             995 non-null    object
#  8   Gender              995 non-null    object
#  9   ReAdmis             1000 non-null   int64
#  10  VitD_levels         1000 non-null   float64
#  11  Doc_visits          1000 non-null   int64
#  12  Full_meals_eaten    1000 non-null   int64
#  13  vitD_supp           1000 non-null   int64
#  14  Soft_drink          1000 non-null   int64
# ...

# %% [markdown]
# #**3. Plot and interpret Graphs**

# %%
# Plot histogram with KDE for VitD_levels
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='density', kde = True)
ax.axvline(mean, color='red', label='Mean');
ax.axvline(median, color='green', label='Median');
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
#ax.set_title(f'{col}')
ax.set_title('Vitamin D levels')
ax.legend();

# %% [markdown]
# ## ** Interpretation **
# - Continuous distribution
# - No Skew, therefore Normal
# - Mesokurtic because values cluster in the middle of the distribution - normal

# %%
# Plot histogram with KDE for Doc_visits
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='density', kde = True)
ax.axvline(mean, color='red', label='Mean');
ax.axvline(median, color='green', label='Median');
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
#ax.set_title(f'{col}')
ax.set_title('Doctor Visits')
ax.legend();

# %% [markdown]
# ## ** Interpretation **
# - Discrete distribution
# - Positively Skewed
# - Leptokurtic because values cluster in the peak of the distribution - positive

# %%
# Plot histogram with KDE for TotalCharge
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='density', kde = True)
ax.axvline(mean, color='red', label='Mean');
ax.axvline(median, color='green', label='Median');
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
#ax.set_title(f'{col}')
ax.set_title('Total Charge')
ax.legend();

# %% [markdown]
# ## ** Interpretation **
# - Continuous distribution
# - Positively Skewed
# - Mesokurtic because values cluster in the middle of the distribution - normal
